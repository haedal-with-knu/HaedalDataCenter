# %% [markdown]
# #### 3.10 분할표 검정
# - 분할 표에 대한 독립성 검정
# - 카이제곱검정 이라고도 한다
# ##### 3.10.1 분할표를 사용할 때의 장점
# ![image.png](attachment:c2aa895f-7c5d-4f5d-8b29-0d586b62b7b6.png)
# ##### 3.10.2 이 절에서 다룰 예제
# ![image.png](attachment:0ab53c74-ceb9-422d-8d3f-e832cc2813e0.png)
# - 관측 도수:실제 관측된 데이터
# - 클릭률이 빨간버튼이 높다. 이게 의미 있는 차이를 가지는지 아닌지 판단해보자

# %% [markdown]
# ##### 3.10.3 기대도수 구하기
# - 기대도수 : 말그대로 기대되는 도수,,
# - 관측 대상의 수가 다음과 같다고 하자
# > 파란버튼 250, 빨간버튼 50
# - 다음중 10%만이 버튼을 누른다고 할 때, 버튼을 누른 사람의 기대도수
# > 파란버튼 25, 빨간버튼 5

# %% [markdown]
# ##### 3.10.4 기대도수와의 차이 구하기
# - 2행 2열 분할표의 경우 카이제곱 통계량의 표본분포는 자유도가 1인 카이제곱분포에 점근적으로 따른다는 것이 증명되어있음
# - 이후는 t검정과 거의 같다

# %% [markdown]
# ##### 3.10.5 p값 계산

# %%
# 수치 계산에 사용하는 라이브러리
import numpy as np
import pandas as pd
import scipy as sp
from scipy import stats
# 그래프를 그리기 위한 라이브러리
from matplotlib import pyplot as plt
import seaborn as sns
sns.set()
#표시 자릿수 지정
# %precision 3
# 그래프를 주피터 노트북에 그리기 위한 설정
# %matplotlib inline

# %%
# 자유도가 1인 카이제곱분포의 누적밀도함수 사용
1 - sp.stats.chi2.cdf(x = 6.667, df = 1)
# Out:
# 0.009821437357809604
